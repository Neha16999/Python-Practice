# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,10,100)

# %%
plt.plot(x,x, label="Linear")

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import matplotlib.pyplot as plt

# %%
x=[100,150,240,300,361,451,620,245,371]
y=[75,95,751,564,852,357,159,965,371]

# %%
plt.scatter(x,y)

# %%
plt.show()

# %%
import numpy as np
import pylab as pl

ds=np.random.normal(6.0, 3.0,100)
pl.hist(ds)
pl.xlabel('ds')
pl.show()
